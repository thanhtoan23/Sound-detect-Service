# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# =========================================================
# 1) LOAD NPZ 
# =========================================================
train = np.load("/kaggle/input/npz-file/pytorch/default/1/train_aug.npz", allow_pickle=True)
val   = np.load("/kaggle/input/npz-file/pytorch/default/1/val.npz", allow_pickle=True)
test  = np.load("/kaggle/input/npz-file/pytorch/default/1/test.npz", allow_pickle=True)
noisy = np.load("/kaggle/input/npz-file/pytorch/default/1/test_noisy.npz", allow_pickle=True)

X_train, y_train = train["X"].astype("float32"), train["y"].astype("int64")
X_val,   y_val   = val["X"].astype("float32"),   val["y"].astype("int64")
X_test,  y_test  = test["X"].astype("float32"),  test["y"].astype("int64")
X_noisy, y_noisy = noisy["X"].astype("float32"), noisy["y"].astype("int64")

classes = train["classes"].tolist()
num_classes = len(classes)
unknown_idx = classes.index("unknown") if "unknown" in classes else None

print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)
print("Noisy:", X_noisy.shape, y_noisy.shape)
print("Num classes:", num_classes)
print("classes:", classes)
print("unknown_idx:", unknown_idx)

def same_classes(a, b):
    return np.array_equal(a["classes"], b["classes"])

print("val classes match train  ?", same_classes(val, train))
print("test classes match train ?", same_classes(test, train))
print("noisy classes match train?", same_classes(noisy, train))


# =========================================================
# 2) ONE-HOT LABELS 
# =========================================================
y_train_oh = tf.one_hot(y_train, depth=num_classes)
y_val_oh   = tf.one_hot(y_val, depth=num_classes)
y_test_oh  = tf.one_hot(y_test, depth=num_classes)
y_noisy_oh = tf.one_hot(y_noisy, depth=num_classes)


# =========================================================
# 3) TF.DATA + SPEC AUGMENT
# =========================================================
BATCH = 64
AUTOTUNE = tf.data.AUTOTUNE

ds_train = tf.data.Dataset.from_tensor_slices((X_train, y_train_oh)).shuffle(6000).batch(BATCH).prefetch(AUTOTUNE)
ds_val   = tf.data.Dataset.from_tensor_slices((X_val, y_val_oh)).batch(BATCH).prefetch(AUTOTUNE)
ds_test  = tf.data.Dataset.from_tensor_slices((X_test, y_test_oh)).batch(BATCH).prefetch(AUTOTUNE)
ds_noisy = tf.data.Dataset.from_tensor_slices((X_noisy, y_noisy_oh)).batch(BATCH).prefetch(AUTOTUNE)

@tf.function
def specaugment(x, y, p=0.9, freq_mask_max=14, time_mask_max=40):
    """
    x: (B, 128, 64, 1)
    y: one-hot (B, num_classes)
    """
    r = tf.random.uniform([])

    def do_aug():
        # Frequency mask
        f = tf.random.uniform([], 0, freq_mask_max + 1, dtype=tf.int32)
        f0 = tf.random.uniform([], 0, 64 - f + 1, dtype=tf.int32)
        freq_mask = tf.concat([
            tf.ones([128, f0, 1]),
            tf.zeros([128, f, 1]),
            tf.ones([128, 64 - f0 - f, 1]),
        ], axis=1)

        # Time mask
        t = tf.random.uniform([], 0, time_mask_max + 1, dtype=tf.int32)
        t0 = tf.random.uniform([], 0, 128 - t + 1, dtype=tf.int32)
        time_mask = tf.concat([
            tf.ones([t0, 64, 1]),
            tf.zeros([t, 64, 1]),
            tf.ones([128 - t0 - t, 64, 1]),
        ], axis=0)

        x2 = x * freq_mask
        x2 = x2 * time_mask
        return x2, y

    return tf.cond(r < p, do_aug, lambda: (x, y))

ds_train_aug = ds_train.map(specaugment, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

# sanity check
xb, yb = next(iter(ds_train_aug))
print("Train batch X:", xb.shape, "y(one-hot):", yb.shape, "min/max:", float(tf.reduce_min(xb)), float(tf.reduce_max(xb)))


# =========================================================
# 4) MODEL: Audio CNN (tăng capacity nhẹ + regularize)
# =========================================================
def build_audio_cnn(input_shape=(128, 64, 1), num_classes=14):
    inp = keras.Input(shape=input_shape)
    x = inp

    for f in [32, 64, 128]:
        x = layers.Conv2D(f, (3,3), padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.Conv2D(f, (3,3), padding="same")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("relu")(x)

        x = layers.MaxPooling2D((2,2))(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Conv2D(256, (3,3), padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inp, out)

model = build_audio_cnn(input_shape=X_train.shape[1:], num_classes=num_classes)

loss_fn = keras.losses.CategoricalCrossentropy(label_smoothing=0.05)

model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=loss_fn,
    metrics=["accuracy"]
)
model.summary()

cbs = [
    keras.callbacks.ModelCheckpoint("best_audio_cnn_v3.keras", monitor="val_loss", save_best_only=True, mode="min"),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=12, restore_best_weights=True, verbose=1),
]


# =========================================================
# 5) CLASS WEIGHT (boost lớp yếu)
# =========================================================
base_counts = np.bincount(y_train, minlength=num_classes).astype(np.float32)
base_weights = base_counts.mean() / (base_counts + 1e-6)
class_weight = {i: float(base_weights[i]) for i in range(num_classes)}

for name, boost in [("engine", 1.8), ("rooster", 1.5), ("dog", 1.3)]:
    if name in classes:
        class_weight[classes.index(name)] *= boost

print("class_weight(sample):", {classes[i]: round(class_weight[i], 3) for i in range(num_classes)})


# =========================================================
# 6) TRAIN
# =========================================================
hist = model.fit(
    ds_train_aug,
    validation_data=ds_val,
    epochs=80,
    callbacks=cbs,
    class_weight=class_weight
)


# =========================================================
# 7) EVALUATE: test clean + test_noisy
# =========================================================
print("\n== TEST clean ==")
model.evaluate(ds_test, verbose=2)

print("\n== TEST noisy ==")
model.evaluate(ds_noisy, verbose=2)


# =========================================================
# 8) THRESHOLD UNKNOWN 
# =========================================================
from sklearn.metrics import f1_score, classification_report

def predict_probs(ds):
    probs, ys = [], []
    for xb, yb in ds:
        probs.append(model.predict(xb, verbose=0))
        ys.append(tf.argmax(yb, axis=1).numpy())  # one-hot -> index
    return np.concatenate(probs, axis=0), np.concatenate(ys, axis=0)

def apply_threshold(prob, unknown_idx, thr):
    pred = prob.argmax(axis=1)
    conf = prob.max(axis=1)
    pred2 = pred.copy()
    pred2[conf < thr] = unknown_idx
    return pred2

if unknown_idx is not None:
    prob_noisy, y_true_noisy = predict_probs(ds_noisy)

    best = None
    for thr in np.arange(0.30, 0.91, 0.05):
        pred_thr = apply_threshold(prob_noisy, unknown_idx, thr)
        f1 = f1_score(y_true_noisy, pred_thr, average="macro")
        if best is None or f1 > best[1]:
            best = (thr, f1)

    print("\nBest threshold on noisy (macro F1):", best)
    thr = best[0]
    pred_thr = apply_threshold(prob_noisy, unknown_idx, thr)

    print("\n=== Classification report (noisy) with threshold thr=%.2f ===" % thr)
    print(classification_report(y_true_noisy, pred_thr, target_names=classes, digits=4))
else:
    print("\n[INFO] Không có class 'unknown' nên bỏ qua threshold tuning.")
# Out:
# Train: (5824, 128, 64, 1) (5824,)
# Val  : (104, 128, 64, 1) (104,)
# Test : (104, 128, 64, 1) (104,)
# Noisy: (104, 128, 64, 1) (104,)
# Num classes: 14
# classes: ['car_horn', 'cat', 'clock_alarm', 'coughing', 'crying_baby', 'dog', 'door_wood_knock', 'engine', 'frog', 'laughing', 'mouse_click', 'rooster', 'unknown', 'water_drops']
# unknown_idx: 12
# val classes match train  ? True
# test classes match train ? True
# noisy classes match train? True
# Train batch X: (64, 128, 64, 1) y(one-hot): (64, 14) min/max: 0.0 1.0
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 128, 64, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 128, 64, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 128, 64, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 128, 64, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 128, 64, 32)    │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 128, 64, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 128, 64, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 64, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 64, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 64, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 64, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 64, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 64, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 64, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 64, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 32, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 32, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 32, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 32, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 32, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 32, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 32, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 16, 8, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 16, 8, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 8, 256)     │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 16, 8, 256)     │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 16, 8, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_6      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 14)             │         3,598 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 588,014 (2.24 MB)
#  Trainable params: 586,606 (2.24 MB)
#  Non-trainable params: 1,408 (5.50 KB)
# class_weight(sample): {'car_horn': 1.0, 'cat': 1.0, 'clock_alarm': 1.0, 'coughing': 1.0, 'crying_baby': 1.0, 'dog': 1.3, 'door_wood_knock': 1.0, 'engine': 1.8, 'frog': 1.0, 'laughing': 1.0, 'mouse_click': 1.0, 'rooster': 1.5, 'unknown': 1.0, 'water_drops': 1.0}
# Epoch 1/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 21s 71ms/step - accuracy: 0.2417 - loss: 2.4992 - val_accuracy: 0.0385 - val_loss: 3.1576 - learning_rate: 0.0010
# Epoch 2/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.5722 - loss: 1.6347 - val_accuracy: 0.0385 - val_loss: 3.4567 - learning_rate: 0.0010
# Epoch 3/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.6803 - loss: 1.3158 - val_accuracy: 0.0385 - val_loss: 3.0473 - learning_rate: 0.0010
# Epoch 4/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.7408 - loss: 1.1540 - val_accuracy: 0.0385 - val_loss: 3.4244 - learning_rate: 0.0010
# Epoch 5/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.7839 - loss: 1.0484 - val_accuracy: 0.3365 - val_loss: 2.4740 - learning_rate: 0.0010
# Epoch 6/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8081 - loss: 0.9808 - val_accuracy: 0.5577 - val_loss: 1.5686 - learning_rate: 0.0010
# Epoch 7/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.8288 - loss: 0.9243 - val_accuracy: 0.5288 - val_loss: 1.6424 - learning_rate: 0.0010
# Epoch 8/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.8408 - loss: 0.9105 - val_accuracy: 0.5673 - val_loss: 1.6025 - learning_rate: 0.0010
# Epoch 9/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.8712 - loss: 0.8192 - val_accuracy: 0.7212 - val_loss: 1.2473 - learning_rate: 0.0010
# Epoch 10/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.8640 - loss: 0.8272 - val_accuracy: 0.4423 - val_loss: 2.4730 - learning_rate: 0.0010
# Epoch 11/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8994 - loss: 0.7604 - val_accuracy: 0.6154 - val_loss: 1.5564 - learning_rate: 0.0010
# Epoch 12/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.8951 - loss: 0.7553 - val_accuracy: 0.7596 - val_loss: 0.9716 - learning_rate: 0.0010
# Epoch 13/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8883 - loss: 0.7579 - val_accuracy: 0.6923 - val_loss: 1.2099 - learning_rate: 0.0010
# Epoch 14/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9075 - loss: 0.7233 - val_accuracy: 0.7596 - val_loss: 1.0596 - learning_rate: 0.0010
# Epoch 15/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9086 - loss: 0.7112 - val_accuracy: 0.8750 - val_loss: 0.8354 - learning_rate: 0.0010
# Epoch 16/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9232 - loss: 0.6785 - val_accuracy: 0.7019 - val_loss: 1.2027 - learning_rate: 0.0010
# Epoch 17/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9244 - loss: 0.6844 - val_accuracy: 0.6154 - val_loss: 1.5174 - learning_rate: 0.0010
# Epoch 18/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9260 - loss: 0.6593
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9259 - loss: 0.6596 - val_accuracy: 0.6923 - val_loss: 1.5392 - learning_rate: 0.0010
# Epoch 19/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9462 - loss: 0.6203 - val_accuracy: 0.8365 - val_loss: 0.7580 - learning_rate: 5.0000e-04
# Epoch 20/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9350 - loss: 0.6470 - val_accuracy: 0.7596 - val_loss: 1.0669 - learning_rate: 5.0000e-04
# Epoch 21/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9481 - loss: 0.6050 - val_accuracy: 0.8365 - val_loss: 0.9259 - learning_rate: 5.0000e-04
# Epoch 22/80
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9500 - loss: 0.5931
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9501 - loss: 0.5930 - val_accuracy: 0.7692 - val_loss: 0.8917 - learning_rate: 5.0000e-04
# Epoch 23/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9576 - loss: 0.5880 - val_accuracy: 0.8750 - val_loss: 0.7170 - learning_rate: 2.5000e-04
# Epoch 24/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9563 - loss: 0.5909 - val_accuracy: 0.8846 - val_loss: 0.6888 - learning_rate: 2.5000e-04
# Epoch 25/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9709 - loss: 0.5468 - val_accuracy: 0.8269 - val_loss: 0.7568 - learning_rate: 2.5000e-04
# Epoch 26/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9653 - loss: 0.5613 - val_accuracy: 0.9231 - val_loss: 0.7173 - learning_rate: 2.5000e-04
# Epoch 27/80
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9649 - loss: 0.5552
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9649 - loss: 0.5554 - val_accuracy: 0.8750 - val_loss: 0.7347 - learning_rate: 2.5000e-04
# Epoch 28/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9683 - loss: 0.5452 - val_accuracy: 0.8750 - val_loss: 0.7105 - learning_rate: 1.2500e-04
# Epoch 29/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9706 - loss: 0.5378 - val_accuracy: 0.8942 - val_loss: 0.6882 - learning_rate: 1.2500e-04
# Epoch 30/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9707 - loss: 0.5384 - val_accuracy: 0.8942 - val_loss: 0.6916 - learning_rate: 1.2500e-04
# Epoch 31/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9733 - loss: 0.5306 - val_accuracy: 0.8654 - val_loss: 0.7743 - learning_rate: 1.2500e-04
# Epoch 32/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9748 - loss: 0.5240
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9748 - loss: 0.5241 - val_accuracy: 0.8942 - val_loss: 0.7090 - learning_rate: 1.2500e-04
# Epoch 33/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9738 - loss: 0.5305 - val_accuracy: 0.8942 - val_loss: 0.7189 - learning_rate: 6.2500e-05
# Epoch 34/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9740 - loss: 0.5250 - val_accuracy: 0.8942 - val_loss: 0.7052 - learning_rate: 6.2500e-05
# Epoch 35/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9812 - loss: 0.5137
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9812 - loss: 0.5138 - val_accuracy: 0.8942 - val_loss: 0.7194 - learning_rate: 6.2500e-05
# Epoch 36/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9702 - loss: 0.5323 - val_accuracy: 0.9135 - val_loss: 0.6777 - learning_rate: 3.1250e-05
# Epoch 37/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9677 - loss: 0.5433 - val_accuracy: 0.9038 - val_loss: 0.6913 - learning_rate: 3.1250e-05
# Epoch 38/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9614 - loss: 0.5500 - val_accuracy: 0.9038 - val_loss: 0.7013 - learning_rate: 3.1250e-05
# Epoch 39/80
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9690 - loss: 0.5473
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9691 - loss: 0.5469 - val_accuracy: 0.9038 - val_loss: 0.6881 - learning_rate: 3.1250e-05
# Epoch 40/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9772 - loss: 0.5212 - val_accuracy: 0.9135 - val_loss: 0.6819 - learning_rate: 1.5625e-05
# Epoch 41/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9661 - loss: 0.5422 - val_accuracy: 0.9135 - val_loss: 0.6958 - learning_rate: 1.5625e-05
# Epoch 42/80
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9757 - loss: 0.5267
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9757 - loss: 0.5266 - val_accuracy: 0.8846 - val_loss: 0.7129 - learning_rate: 1.5625e-05
# Epoch 43/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9769 - loss: 0.5216 - val_accuracy: 0.8942 - val_loss: 0.7024 - learning_rate: 7.8125e-06
# Epoch 44/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9735 - loss: 0.5269 - val_accuracy: 0.8942 - val_loss: 0.6998 - learning_rate: 7.8125e-06
# Epoch 45/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9790 - loss: 0.5104
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9790 - loss: 0.5105 - val_accuracy: 0.8942 - val_loss: 0.6983 - learning_rate: 7.8125e-06
# Epoch 46/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9742 - loss: 0.5228 - val_accuracy: 0.8942 - val_loss: 0.6989 - learning_rate: 3.9063e-06
# Epoch 47/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9768 - loss: 0.5197 - val_accuracy: 0.8942 - val_loss: 0.7031 - learning_rate: 3.9063e-06
# Epoch 48/80
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9725 - loss: 0.5279
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9725 - loss: 0.5278 - val_accuracy: 0.9038 - val_loss: 0.6990 - learning_rate: 3.9063e-06
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 36.
#
# == TEST clean ==
# 2/2 - 0s - 14ms/step - accuracy: 0.8269 - loss: 0.8450
#
# == TEST noisy ==
# 2/2 - 0s - 14ms/step - accuracy: 0.7596 - loss: 1.1412
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a11402b0360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a11402b0360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# Best threshold on noisy (macro F1): (0.5999999999999999, 0.8266959120096636)
#
# === Classification report (noisy) with threshold thr=0.60 ===
#                  precision    recall  f1-score   support
#
#        car_horn     1.0000    1.0000    1.0000         4
#             cat     1.0000    1.0000    1.0000         4
#     clock_alarm     1.0000    0.7500    0.8571         4
#        coughing     0.6000    0.7500    0.6667         4
#     crying_baby     1.0000    1.0000    1.0000         4
#             dog     1.0000    0.5000    0.6667         4
# door_wood_knock     0.6667    1.0000    0.8000         4
#          engine     0.6667    0.5000    0.5714         4
#            frog     1.0000    0.5000    0.6667         4
#        laughing     0.6667    1.0000    0.8000         4
#     mouse_click     1.0000    1.0000    1.0000         4
#         rooster     1.0000    1.0000    1.0000         4
#         unknown     0.8545    0.9038    0.8785        52
#     water_drops     1.0000    0.5000    0.6667         4
#
#        accuracy                         0.8558       104
#       macro avg     0.8896    0.8146    0.8267       104
#    weighted avg     0.8734    0.8558    0.8506       104

# %%
best = keras.models.load_model("best_audio_cnn_v3.keras", compile=False)
best.save("audio_cnn_best.h5")
print("Saved: audio_cnn_best.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved: audio_cnn_best.h5
